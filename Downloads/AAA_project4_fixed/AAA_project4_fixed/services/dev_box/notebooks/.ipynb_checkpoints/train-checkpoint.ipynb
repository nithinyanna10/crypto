# %%
import os
import json
import joblib
import duckdb
import optuna
import talib
import lightgbm as lgb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

from datetime import datetime, timedelta
from sklearn.metrics import (
    classification_report, accuracy_score, precision_score, recall_score, f1_score
)

# 1. Fetch last 30 days of candles
def fetch_recent_candles(duckdb_file, table_name, days=30):
    now = datetime.utcnow()
    start_time = now - timedelta(days=days)
    query = f"""
        SELECT * FROM {table_name}
        WHERE interval_start >= '{start_time.strftime('%Y-%m-%d %H:%M:%S')}'
        ORDER BY interval_start
    """
    with duckdb.connect(duckdb_file) as conn:
        df = conn.execute(query).fetchdf()
    return df

# 2. Feature engineering (with tunable parameters)
def generate_features(
    candles,
    rolling_volatility_window=30,
    trix_period=30,
    tema_period=30,
    bbands_period=20,
    macd_fast=12,
    macd_slow=26,
    obv_window=30,
    ewma_span=10,
    predict_horizon_minutes=5  # Fixed
):
    candles = candles.copy()
    candles['interval_start'] = pd.to_datetime(candles['interval_start'])
    candles['interval_end'] = pd.to_datetime(candles['interval_end'])
    candles['future_close'] = candles['close_price'].shift(-predict_horizon_minutes)
    candles['target_return'] = (candles['future_close'] - candles['close_price']) / candles['close_price']
    candles['signal'] = (candles['target_return'] > 0).astype(int)

    candles['rolling_volatility'] = candles['close_price'].rolling(window=rolling_volatility_window).std()
    candles['volume_spike'] = candles['volume'] / candles['volume'].rolling(window=rolling_volatility_window).mean()
    candles['minute_of_day'] = candles['interval_start'].dt.hour * 60 + candles['interval_start'].dt.minute
    candles['momentum_5'] = candles['close_price'].pct_change(5)
    candles['momentum_15'] = candles['close_price'].pct_change(15)
    candles['range_ratio'] = (candles['high_price'] - candles['low_price']) / candles['close_price']
    candles['slope_10'] = candles['close_price'].diff(10) / 10
    candles['day_of_week'] = candles['interval_start'].dt.dayofweek
    candles['hour_sin'] = np.sin(2 * np.pi * candles['interval_start'].dt.hour / 24)
    candles['hour_cos'] = np.cos(2 * np.pi * candles['interval_start'].dt.hour / 24)

    us_market_open = 13
    asia_market_open = 1
    europe_market_open = 7

    def minutes_from_market(hour, minute, market_hour):
        mins = hour * 60 + minute
        delta = mins - market_hour * 60
        if delta < 0:
            delta += 1440
        return delta

    candles['minutes_from_us_open'] = candles['interval_start'].apply(lambda x: minutes_from_market(x.hour, x.minute, us_market_open))
    candles['minutes_from_asia_open'] = candles['interval_start'].apply(lambda x: minutes_from_market(x.hour, x.minute, asia_market_open))
    candles['minutes_from_europe_open'] = candles['interval_start'].apply(lambda x: minutes_from_market(x.hour, x.minute, europe_market_open))

    for market in ['us', 'asia', 'europe']:
        candles[f'norm_{market}_time'] = candles[f'minutes_from_{market}_open'] / 1440
        candles[f'{market}_time_sin'] = np.sin(2 * np.pi * candles[f'norm_{market}_time'])
        candles[f'{market}_time_cos'] = np.cos(2 * np.pi * candles[f'norm_{market}_time'])

    candles['trix'] = talib.TRIX(candles['close_price'].values, timeperiod=trix_period)
    candles['tema'] = talib.TEMA(candles['close_price'].values, timeperiod=tema_period)
    candles['dx'] = talib.DX(candles['high_price'].values, candles['low_price'].values, candles['close_price'].values)
    candles['sar'] = talib.SAR(candles['high_price'].values, candles['low_price'].values)
    candles['atr'] = talib.ATR(candles['high_price'].values, candles['low_price'].values, candles['close_price'].values)
    candles['volume_ema'] = candles['volume'].ewm(span=20).mean()
    candles['volume_ratio'] = candles['volume'] / candles['volume_ema']
    candles['volume_oscillator'] = (candles['volume'].rolling(window=5).mean() / candles['volume'].rolling(window=20).mean() - 1) * 100

    candles['vwap_daily'] = 0.0
    for date in candles['interval_start'].dt.date.unique():
        mask = candles['interval_start'].dt.date == date
        if mask.any():
            candles.loc[mask, 'vwap_daily'] = (candles.loc[mask, 'volume'] * candles.loc[mask, 'close_price']).cumsum() / candles.loc[mask, 'volume'].cumsum()
    candles['vwap_ratio'] = candles['close_price'] / candles['vwap_daily'].replace(0, np.nan)

    candles['adx'] = talib.ADX(candles['high_price'].values, candles['low_price'].values, candles['close_price'].values)
    candles['adx_strong'] = (candles['adx'] > 25).astype(int)
    candles['obv'] = talib.OBV(candles['close_price'].values, candles['volume'].values)
    candles['obv_rolling'] = candles['obv'].rolling(window=obv_window).mean()
    candles['willr'] = talib.WILLR(candles['high_price'].values, candles['low_price'].values, candles['close_price'].values)
    candles['mfi'] = talib.MFI(candles['high_price'].values, candles['low_price'].values, candles['close_price'].values, candles['volume'].values)
    candles['rsi'] = talib.RSI(candles['close_price'].values)

    # EWMA features
    candles['ewma_close'] = candles['close_price'].ewm(span=ewma_span).mean()
    candles['ewma_volume'] = candles['volume'].ewm(span=ewma_span).mean()

    # MACD with optimized fast/slow
    candles['macd'], candles['macd_signal'], candles['macd_hist'] = talib.MACD(
        candles['close_price'].values, fastperiod=macd_fast, slowperiod=macd_slow)

    for period in [5, 10, 20]:
        candles[f'direction_{period}'] = np.sign(candles['close_price'].diff(period)).fillna(0).astype(int)
        candles[f'sma_{period}'] = candles['close_price'].rolling(window=period).mean()
        candles[f'above_sma_{period}'] = (candles['close_price'] > candles[f'sma_{period}']).astype(int)

    sma_5 = candles['close_price'].rolling(window=5).mean()
    for period in [10, 20]:
        sma_period = candles['close_price'].rolling(window=period).mean()
        candles[f'ma_crossover_{period}'] = ((sma_5 > sma_period) & (sma_5.shift(1) <= sma_period.shift(1))).astype(int)

    candles['bb_upper'], candles['bb_middle'], candles['bb_lower'] = talib.BBANDS(
        candles['close_price'].values, timeperiod=bbands_period)
    candles['bb_width'] = (candles['bb_upper'] - candles['bb_lower']) / candles['bb_middle']
    candles['bb_position'] = (candles['close_price'] - candles['bb_lower']) / (candles['bb_upper'] - candles['bb_lower'])
    candles['atr_ratio'] = candles['atr'] / candles['close_price']

    # Additional MACD variants (fixed)
    for fast, slow in [(12, 26), (5, 35)]:
        macd, macd_signal, macd_hist = talib.MACD(candles['close_price'].values, fastperiod=fast, slowperiod=slow)
        candles[f'macd_{fast}_{slow}'] = macd
        candles[f'macd_signal_{fast}_{slow}'] = macd_signal
        candles[f'macd_hist_{fast}_{slow}'] = macd_hist
        candles[f'macd_cross_{fast}_{slow}'] = ((macd > macd_signal) & (np.roll(macd, 1) <= np.roll(macd_signal, 1))).astype(int)

    candles['time_segment'] = pd.cut(candles['minute_of_day'], bins=[0, 360, 720, 1080, 1440], labels=['night', 'morning', 'afternoon', 'evening'])
    for segment in ['night', 'morning', 'afternoon', 'evening']:
        candles[f'time_{segment}'] = (candles['time_segment'] == segment).astype(int)

    candles['obv_trend'] = candles['obv'] * candles['adx']
    candles['volume_volatility'] = candles['volume_ratio'] * candles['rolling_volatility']
    candles['time_volume'] = candles['minute_of_day'] * candles['volume_ratio']

    candles.fillna(candles.mean(numeric_only=True), inplace=True)
    return candles

# 3. Prepare train/test split
def prepare_train_test_split(candles, feature_columns):
    cutoff = int(len(candles) * 0.80)
    train_data = candles.iloc[:cutoff]
    test_data = candles.iloc[cutoff:]
    X_train = train_data[feature_columns]
    y_train = train_data['signal']
    X_test = test_data[feature_columns]
    y_test = test_data['signal']
    return X_train, y_train, X_test, y_test, train_data, test_data

# 4. Optuna optimization (feature params + model params)
def run_optuna_optimization(df, feature_columns, n_trials=200):
    def objective(trial):
        rolling_volatility_window = trial.suggest_int('rolling_volatility_window', 10, 60)
        trix_period = trial.suggest_int('trix_period', 10, 70)
        tema_period = trial.suggest_int('tema_period', 10, 70)
        bbands_period = trial.suggest_int('bbands_period', 10, 40)
        macd_fast = trial.suggest_int('macd_fast', 1, 19)
        macd_slow = trial.suggest_int('macd_slow', macd_fast + 1, 40)
        obv_window = trial.suggest_int('obv_window', 5, 60)
        ewma_span = trial.suggest_int('ewma_span', 3, 40)

        try:
            candles = generate_features(
                df,
                rolling_volatility_window=rolling_volatility_window,
                trix_period=trix_period,
                tema_period=tema_period,
                bbands_period=bbands_period,
                macd_fast=macd_fast,
                macd_slow=macd_slow,
                obv_window=obv_window,
                ewma_span=ewma_span,
                predict_horizon_minutes=5
            )
        except Exception as e:
            raise optuna.TrialPruned()

        X_train, y_train, X_test, y_test, train_data, test_data = prepare_train_test_split(candles, feature_columns)

        params = {
            'objective': 'binary',
            'num_leaves': trial.suggest_int('num_leaves', 30, 70),
            'learning_rate': trial.suggest_float('learning_rate', 0.03, 0.08),
            'n_estimators': trial.suggest_int('n_estimators', 200, 500),
            'min_child_samples': trial.suggest_int('min_child_samples', 10, 30),
            'subsample': trial.suggest_float('subsample', 0.65, 0.9),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 0.9),
            'reg_alpha': trial.suggest_float('reg_alpha', 0.6, 1.0),
            'reg_lambda': trial.suggest_float('reg_lambda', 0.2, 1.0),
            'class_weight': 'balanced',
            'verbosity': -1
        }
        model = lgb.LGBMClassifier(**params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        y_proba = model.predict_proba(X_test)[:, 1]
        # sim_df = run_simulation(test_data, y_pred, y_proba, strategy='balanced')
        sim_dyn = run_simulation(test_data, y_pred, y_proba, 'dynamic')  
        sim_bal = run_simulation(test_data, y_pred, y_proba, 'balanced')  
        sim_ultra = run_simulation(test_data, y_pred, y_proba, 'ultra_aggressive')  
        # For example, maximize the average of all three  
        return (sim_dyn['balance'].iloc[-1] + sim_bal['balance'].iloc[-1] + sim_ultra['balance'].iloc[-1]) / 3
        # return sim_df['balance'].iloc[-1]

    study = optuna.create_study(direction='maximize')
    study.optimize(objective, n_trials=n_trials)
    return study.best_params

# 5. Simulation function
def run_simulation(sim_data, y_pred, y_pred_proba, strategy, initial_balance=10000):
    balance_history = []
    balance = initial_balance
    position = 0
    sim_data = sim_data.copy()
    sim_data['predicted'] = y_pred
    sim_data['predicted_proba'] = y_pred_proba
    for i in range(0, len(sim_data), 5):
        row = sim_data.iloc[i]
        price = row['close_price']
        signal = row['predicted']
        confidence = row['predicted_proba']
        if strategy == 'dynamic':
            if signal == 1 and confidence > 0.55 and balance > 0:
                position_size = balance * min(0.25 + (confidence - 0.55), 0.5)
                units = position_size / price
                position += units
                balance -= position_size
            elif signal == 0 and position > 0:
                units_to_sell = position * 0.75
                balance += units_to_sell * price
                position -= units_to_sell
        elif strategy == 'balanced':
            if signal == 1 and confidence > 0.6 and balance > 0:
                position_size = balance * 0.25
                units = position_size / price
                position += units
                balance -= position_size
            elif signal == 0 and position > 0:
                units_to_sell = position * 0.75
                balance += units_to_sell * price
                position -= units_to_sell
        elif strategy == 'ultra_aggressive':
            if signal == 1 and confidence > 0.5 and balance > 0:
                position_size = min(balance * 0.5, balance)
                units = position_size / price
                position += units
                balance -= position_size
            elif signal == 0 and position > 0:
                units_to_sell = position * 0.5
                balance += units_to_sell * price
                position -= units_to_sell
        current_balance = balance + (position * price if position > 0 else 0)
        balance_history.append((row['interval_start'], current_balance))
    return pd.DataFrame(balance_history, columns=['time', 'balance'])

# 6. Plotting and printing balances
def plot_and_print_balances(balance_df_dyn, balance_df_bal, balance_df_ultra, initial_balance=10000):
    print("Final Portfolio Balances:")
    print(f"Dynamic Strategy Final Balance: ${balance_df_dyn['balance'].iloc[-1]:.2f}")
    print(f"Balanced Final Balance: ${balance_df_bal['balance'].iloc[-1]:.2f}")
    print(f"Ultra-Aggressive Final Balance: ${balance_df_ultra['balance'].iloc[-1]:.2f}")

    plt.figure(figsize=(12, 5))
    plt.plot(balance_df_dyn['time'], balance_df_dyn['balance'], label='Dynamic')
    plt.plot(balance_df_bal['time'], balance_df_bal['balance'], label='Balanced')
    plt.plot(balance_df_ultra['time'], balance_df_ultra['balance'], label='Ultra-Aggressive')
    plt.axhline(y=initial_balance, color='red', linestyle='--', label='Initial Capital')
    plt.title('Portfolio Balance Comparison')
    plt.xlabel('Time')
    plt.ylabel('Balance (USD)')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def train_on_full_data(candles, feature_columns, best_params):
    X_full = candles[feature_columns]
    y_full = candles['signal']
    final_model = lgb.LGBMClassifier(**best_params)
    final_model.fit(X_full, y_full)
    return final_model


def save_model(model, model_dir="/data/models"):
    os.makedirs(model_dir, exist_ok=True)
    now_str = datetime.utcnow().strftime("%Y%m%d_%H%M%S")
    run_dir = os.path.join(model_dir, f"run_{now_str}")
    os.makedirs(run_dir, exist_ok=True)
    model_path = os.path.join(run_dir, "model.pkl")
    joblib.dump(model, model_path)
    # Atomic update for latest.pkl
    tmp_path = os.path.join(model_dir, "latest_tmp.pkl")
    latest_path = os.path.join(model_dir, "latest.pkl")
    joblib.dump(model, tmp_path)
    os.replace(tmp_path, latest_path)  # Atomic on most OSes
    return run_dir, model_path, latest_path



def save_metadata(run_dir, best_params, accuracy, precision, recall, f1, balance_df_dyn, balance_df_bal, balance_df_ultra, duration, model_dir="/data/models"):
    now_str = datetime.utcnow().strftime("%Y%m%d_%H%M%S")
    metrics = {
        "timestamp": now_str,
        "best_params": best_params,
        "accuracy": round(accuracy, 4),
        "precision": round(precision, 4),
        "recall": round(recall, 4),
        "f1_score": round(f1, 4),
        "duration_seconds": round(duration, 2),
        "portfolio_balances": {
            "dynamic": round(balance_df_dyn['balance'].iloc[-1], 2),
            "balanced": round(balance_df_bal['balance'].iloc[-1], 2),
            "ultra_aggressive": round(balance_df_ultra['balance'].iloc[-1], 2)
        }
    }
    # Save to run-specific folder atomically
    metrics_path = os.path.join(run_dir, "metrics.json")
    tmp_metrics_path = os.path.join(run_dir, "metrics_tmp.json")
    with open(tmp_metrics_path, "w") as f:
        json.dump(metrics, f, indent=4)
    os.replace(tmp_metrics_path, metrics_path)  # Atomic move

    # Also save as latest.json in the model_dir atomically
    latest_metrics_path = os.path.join(model_dir, "latest.json")
    tmp_latest_metrics_path = os.path.join(model_dir, "latest_tmp.json")
    with open(tmp_latest_metrics_path, "w") as f:
        json.dump(metrics, f, indent=4)
    os.replace(tmp_latest_metrics_path, latest_metrics_path)  # Atomic move

    return metrics_path, latest_metrics_path

def main():
    start_time = time.time()  # Start timer for the whole process

    duckdb_file = '/data/crypto.duckdb'
    table_name = 'candles'
    initial_balance = 10000

    feature_columns = [
        'rsi', 'macd', 'macd_signal', 'macd_hist', 'adx', 'obv', 'obv_rolling', 'willr', 'mfi',
        'trix', 'tema', 'dx', 'sar', 'atr', 'rolling_volatility', 'volume_spike',
        'minute_of_day', 'momentum_5', 'momentum_15', 'range_ratio', 'slope_10',
        'day_of_week', 'hour_sin', 'hour_cos', 'minutes_from_us_open',
        'minutes_from_asia_open', 'minutes_from_europe_open', 'us_time_sin',
        'us_time_cos', 'asia_time_sin', 'asia_time_cos', 'europe_time_sin',
        'europe_time_cos', 'volume_ema', 'volume_ratio', 'volume_oscillator',
        'vwap_ratio', 'adx_strong', 'direction_5', 'direction_10', 'direction_20',
        'above_sma_5', 'above_sma_10', 'above_sma_20', 'bb_width', 'bb_position',
        'atr_ratio', 'macd_12_26', 'macd_signal_12_26', 'macd_hist_12_26',
        'macd_5_35', 'macd_signal_5_35', 'macd_hist_5_35', 'macd_cross_12_26',
        'macd_cross_5_35', 'time_night', 'time_morning', 'time_afternoon',
        'time_evening', 'obv_trend', 'volume_volatility', 'time_volume',
        'ewma_close', 'ewma_volume'  
    ]

    df = fetch_recent_candles(duckdb_file, table_name)
    best_params = run_optuna_optimization(df, feature_columns, n_trials=200)

    # Extract feature params for final feature generation
    feature_param_keys = [
        'rolling_volatility_window', 'trix_period',
        'tema_period', 'bbands_period', 'macd_fast', 'macd_slow', 'obv_window', 'ewma_span'
    ]
    feature_params = {k: best_params[k] for k in feature_param_keys}
    model_params = {k: v for k, v in best_params.items() if k not in feature_param_keys}

    candles = generate_features(df, **feature_params, predict_horizon_minutes=5)
    X_train, y_train, X_test, y_test, train_data, test_data = prepare_train_test_split(candles, feature_columns)
    best_model = lgb.LGBMClassifier(**model_params)
    best_model.fit(X_train, y_train)
    y_pred = best_model.predict(X_test)
    y_pred_proba = best_model.predict_proba(X_test)[:, 1]

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    balance_df_dyn = run_simulation(test_data, y_pred, y_pred_proba, 'dynamic', initial_balance)
    balance_df_bal = run_simulation(test_data, y_pred, y_pred_proba, 'balanced', initial_balance)
    balance_df_ultra = run_simulation(test_data, y_pred, y_pred_proba, 'ultra_aggressive', initial_balance)

    plot_and_print_balances(balance_df_dyn, balance_df_bal, balance_df_ultra, initial_balance)

    # Train on full data and save model
    final_model = train_on_full_data(candles, feature_columns, model_params)
    run_dir, model_path, latest_path = save_model(final_model, model_dir="/data/models")
    end_time = time.time()
    duration = end_time - start_time
    save_metadata(run_dir, best_params, accuracy, precision, recall, f1, balance_df_dyn, balance_df_bal, balance_df_ultra, duration
                 )

    print(f"\nTotal process duration: {duration:.2f} seconds ({duration/60:.2f} minutes).")

if __name__ == "__main__":
    # 50 * * * * /usr/bin/python3 /path/to/train.py
    main()
# Out:
# [I 2025-05-04 23:49:45,084] A new study created in memory with name: no-name-70133879-957f-467b-b592-34f07e53ab5e
# [I 2025-05-04 23:49:49,409] Trial 0 finished with value: 10248.073566443594 and parameters: {'rolling_volatility_window': 43, 'trix_period': 14, 'tema_period': 10, 'bbands_period': 24, 'macd_fast': 12, 'macd_slow': 23, 'obv_window': 26, 'ewma_span': 26, 'num_leaves': 69, 'learning_rate': 0.06597744463164984, 'n_estimators': 314, 'min_child_samples': 28, 'subsample': 0.7774017471860369, 'colsample_bytree': 0.8326743659729122, 'reg_alpha': 0.6459068081117618, 'reg_lambda': 0.843567774694626}. Best is trial 0 with value: 10248.073566443594.
# [I 2025-05-04 23:49:53,659] Trial 1 finished with value: 10176.492958354027 and parameters: {'rolling_volatility_window': 18, 'trix_period': 69, 'tema_period': 53, 'bbands_period': 19, 'macd_fast': 18, 'macd_slow': 20, 'obv_window': 17, 'ewma_span': 15, 'num_leaves': 64, 'learning_rate': 0.032117538173902546, 'n_estimators': 362, 'min_child_samples': 20, 'subsample': 0.796289724691458, 'colsample_bytree': 0.7761549333258921, 'reg_alpha': 0.9417295667139041, 'reg_lambda': 0.9512447010318075}. Best is trial 0 with value: 10248.073566443594.
# [I 2025-05-04 23:49:58,179] Trial 2 finished with value: 10287.193398803687 and parameters: {'rolling_volatility_window': 14, 'trix_period': 41, 'tema_period': 48, 'bbands_period': 37, 'macd_fast': 12, 'macd_slow': 37, 'obv_window': 37, 'ewma_span': 9, 'num_leaves': 65, 'learning_rate': 0.050653831302386904, 'n_estimators': 412, 'min_child_samples': 20, 'subsample': 0.7185298630443137, 'colsample_bytree': 0.8918369141754043, 'reg_alpha': 0.7618525539019296, 'reg_lambda': 0.8469911290593266}. Best is trial 2 with value: 10287.193398803687.
# [I 2025-05-04 23:50:02,070] Trial 3 finished with value: 10257.852065304702 and parameters: {'rolling_volatility_window': 45, 'trix_period': 45, 'tema_period': 25, 'bbands_period': 33, 'macd_fast': 10, 'macd_slow': 38, 'obv_window': 17, 'ewma_span': 13, 'num_leaves': 65, 'learning_rate': 0.036793223930275204, 'n_estimators': 284, 'min_child_samples': 22, 'subsample': 0.8873856572909524, 'colsample_bytree': 0.8404683320839201, 'reg_alpha': 0.8980575031729565, 'reg_lambda': 0.5863107028581369}. Best is trial 2 with value: 10287.193398803687.
# [I 2025-05-04 23:50:07,068] Trial 4 finished with value: 10255.830139476608 and parameters: {'rolling_volatility_window': 37, 'trix_period': 60, 'tema_period': 63, 'bbands_period': 25, 'macd_fast': 18, 'macd_slow': 26, 'obv_window': 28, 'ewma_span': 27, 'num_leaves': 67, 'learning_rate': 0.052902785275437875, 'n_estimators': 470, 'min_child_samples': 19, 'subsample': 0.8661075538275465, 'colsample_bytree': 0.7619817242361212, 'reg_alpha': 0.6072847028970959, 'reg_lambda': 0.4533393210611104}. Best is trial 2 with value: 10287.193398803687.
# /usr/local/lib/python3.11/site-packages/numpy/_core/_methods.py:52: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# [I 2025-05-04 23:50:09,336] Trial 5 finished with value: 10285.075251319779 and parameters: {'rolling_volatility_window': 17, 'trix_period': 23, 'tema_period': 62, 'bbands_period': 12, 'macd_fast': 14, 'macd_slow': 39, 'obv_window': 18, 'ewma_span': 33, 'num_leaves': 38, 'learning_rate': 0.06938632444989977, 'n_estimators': 251, 'min_child_samples': 14, 'subsample': 0.8639799097560796, 'colsample_bytree': 0.7658526826431888, 'reg_alpha': 0.7901862965783938, 'reg_lambda': 0.5823366423265878}. Best is trial 2 with value: 10287.193398803687.
# [I 2025-05-04 23:50:10,160] Trial 6 finished with value: 10323.909610164936 and parameters: {'rolling_volatility_window': 57, 'trix_period': 56, 'tema_period': 39, 'bbands_period': 33, 'macd_fast': 18, 'macd_slow': 34, 'obv_window': 26, 'ewma_span': 4, 'num_leaves': 45, 'learning_rate': 0.06493327566501575, 'n_estimators': 256, 'min_child_samples': 13, 'subsample': 0.7746628126261709, 'colsample_bytree': 0.8983750937819972, 'reg_alpha': 0.6983605047871662, 'reg_lambda': 0.693172651131172}. Best is trial 6 with value: 10323.909610164936.
# [I 2025-05-04 23:50:15,877] Trial 7 finished with value: 10249.962867604394 and parameters: {'rolling_volatility_window': 27, 'trix_period': 31, 'tema_period': 48, 'bbands_period': 24, 'macd_fast': 8, 'macd_slow': 39, 'obv_window': 40, 'ewma_span': 10, 'num_leaves': 41, 'learning_rate': 0.03577403493513166, 'n_estimators': 460, 'min_child_samples': 21, 'subsample': 0.7839575053723893, 'colsample_bytree': 0.7596325016728476, 'reg_alpha': 0.8048252558560312, 'reg_lambda': 0.7450129647369599}. Best is trial 6 with value: 10323.909610164936.
# [I 2025-05-04 23:50:18,893] Trial 8 finished with value: 10198.021363045045 and parameters: {'rolling_volatility_window': 53, 'trix_period': 62, 'tema_period': 15, 'bbands_period': 20, 'macd_fast': 18, 'macd_slow': 19, 'obv_window': 35, 'ewma_span': 25, 'num_leaves': 57, 'learning_rate': 0.058525958856021604, 'n_estimators': 297, 'min_child_samples': 30, 'subsample': 0.838015156399553, 'colsample_bytree': 0.7957339308375028, 'reg_alpha': 0.7879796010239919, 'reg_lambda': 0.2803176027997527}. Best is trial 6 with value: 10323.909610164936.
# [I 2025-05-04 23:50:22,467] Trial 9 finished with value: 10125.516966026495 and parameters: {'rolling_volatility_window': 50, 'trix_period': 12, 'tema_period': 46, 'bbands_period': 31, 'macd_fast': 14, 'macd_slow': 26, 'obv_window': 49, 'ewma_span': 39, 'num_leaves': 51, 'learning_rate': 0.07238532503487757, 'n_estimators': 389, 'min_child_samples': 12, 'subsample': 0.8572104971026555, 'colsample_bytree': 0.6621325687271862, 'reg_alpha': 0.752381292801781, 'reg_lambda': 0.41519948143889523}. Best is trial 6 with value: 10323.909610164936.
# [I 2025-05-04 23:50:24,560] Trial 10 finished with value: 10266.19376200704 and parameters: {'rolling_volatility_window': 56, 'trix_period': 51, 'tema_period': 30, 'bbands_period': 40, 'macd_fast': 4, 'macd_slow': 5, 'obv_window': 58, 'ewma_span': 4, 'num_leaves': 31, 'learning_rate': 0.07947850840146305, 'n_estimators': 200, 'min_child_samples': 15, 'subsample': 0.6856695602312526, 'colsample_bytree': 0.6835015875836421, 'reg_alpha': 0.6850488487717528, 'reg_lambda': 0.6825183223337787}. Best is trial 6 with value: 10323.909610164936.
# [I 2025-05-04 23:50:24,909] Trial 11 pruned.
# [I 2025-05-04 23:50:29,339] Trial 12 finished with value: 10269.273224257091 and parameters: {'rolling_volatility_window': 11, 'trix_period': 50, 'tema_period': 38, 'bbands_period': 33, 'macd_fast': 15, 'macd_slow': 33, 'obv_window': 43, 'ewma_span': 9, 'num_leaves': 49, 'learning_rate': 0.04831028067709687, 'n_estimators': 408, 'min_child_samples': 10, 'subsample': 0.7097747827384135, 'colsample_bytree': 0.8878917121838973, 'reg_alpha': 0.6924956916062595, 'reg_lambda': 0.9538553113342655}. Best is trial 6 with value: 10323.909610164936.
# [I 2025-05-04 23:50:35,409] Trial 13 finished with value: 10313.43082269361 and parameters: {'rolling_volatility_window': 60, 'trix_period': 37, 'tema_period': 54, 'bbands_period': 36, 'macd_fast': 8, 'macd_slow': 32, 'obv_window': 31, 'ewma_span': 16, 'num_leaves': 56, 'learning_rate': 0.044943717104958425, 'n_estimators': 431, 'min_child_samples': 24, 'subsample': 0.7117238741205111, 'colsample_bytree': 0.893920212164214, 'reg_alpha': 0.8628679481906789, 'reg_lambda': 0.7987938724560188}. Best is trial 6 with value: 10323.909610164936.
# [I 2025-05-04 23:50:38,224] Trial 14 finished with value: 10186.256003679488 and parameters: {'rolling_volatility_window': 59, 'trix_period': 28, 'tema_period': 68, 'bbands_period': 30, 'macd_fast': 7, 'macd_slow': 31, 'obv_window': 25, 'ewma_span': 19, 'num_leaves': 54, 'learning_rate': 0.045284915683385725, 'n_estimators': 496, 'min_child_samples': 25, 'subsample': 0.6505017727912368, 'colsample_bytree': 0.8439999453435466, 'reg_alpha': 0.8596907366263121, 'reg_lambda': 0.7374110247725209}. Best is trial 6 with value: 10323.909610164936.
# [I 2025-05-04 23:50:40,551] Trial 15 finished with value: 10181.83372452323 and parameters: {'rolling_volatility_window': 60, 'trix_period': 55, 'tema_period': 56, 'bbands_period': 35, 'macd_fast': 6, 'macd_slow': 29, 'obv_window': 8, 'ewma_span': 17, 'num_leaves': 45, 'learning_rate': 0.05997916295644995, 'n_estimators': 208, 'min_child_samples': 17, 'subsample': 0.742673138861673, 'colsample_bytree': 0.6964329828853612, 'reg_alpha': 0.8545102738078487, 'reg_lambda': 0.8159142867547704}. Best is trial 6 with value: 10323.909610164936.
# [I 2025-05-04 23:50:44,646] Trial 16 finished with value: 10226.135697511067 and parameters: {'rolling_volatility_window': 49, 'trix_period': 36, 'tema_period': 25, 'bbands_period': 30, 'macd_fast': 4, 'macd_slow': 14, 'obv_window': 30, 'ewma_span': 21, 'num_leaves': 58, 'learning_rate': 0.04163869000873231, 'n_estimators': 348, 'min_child_samples': 25, 'subsample': 0.7485623950202068, 'colsample_bytree': 0.895894283720204, 'reg_alpha': 0.9867894914991583, 'reg_lambda': 0.6423726570821491}. Best is trial 6 with value: 10323.909610164936.
# [I 2025-05-04 23:50:46,838] Trial 17 finished with value: 10345.873730571659 and parameters: {'rolling_volatility_window': 44, 'trix_period': 69, 'tema_period': 42, 'bbands_period': 37, 'macd_fast': 10, 'macd_slow': 35, 'obv_window': 48, 'ewma_span': 6, 'num_leaves': 44, 'learning_rate': 0.06235479363259362, 'n_estimators': 248, 'min_child_samples': 24, 'subsample': 0.8046802614939674, 'colsample_bytree': 0.613690994734805, 'reg_alpha': 0.7180861000496371, 'reg_lambda': 0.5062571846158405}. Best is trial 17 with value: 10345.873730571659.
# [I 2025-05-04 23:50:49,088] Trial 18 finished with value: 10276.502660231943 and parameters: {'rolling_volatility_window': 39, 'trix_period': 70, 'tema_period': 31, 'bbands_period': 28, 'macd_fast': 16, 'macd_slow': 35, 'obv_window': 49, 'ewma_span': 6, 'num_leaves': 35, 'learning_rate': 0.06431351140898449, 'n_estimators': 255, 'min_child_samples': 16, 'subsample': 0.8152315916747978, 'colsample_bytree': 0.6119768728945347, 'reg_alpha': 0.7063353874015632, 'reg_lambda': 0.48916636482258496}. Best is trial 17 with value: 10345.873730571659.
# [I 2025-05-04 23:50:51,585] Trial 19 finished with value: 10263.610427568608 and parameters: {'rolling_volatility_window': 45, 'trix_period': 63, 'tema_period': 41, 'bbands_period': 37, 'macd_fast': 11, 'macd_slow': 29, 'obv_window': 60, 'ewma_span': 12, 'num_leaves': 44, 'learning_rate': 0.07588418573124554, 'n_estimators': 248, 'min_child_samples': 10, 'subsample': 0.8095288817918485, 'colsample_bytree': 0.6083041341944364, 'reg_alpha': 0.7271043203147686, 'reg_lambda': 0.28939197753721835}. Best is trial 17 with value: 10345.873730571659.
# [I 2025-05-04 23:50:54,792] Trial 20 finished with value: 10168.125291541355 and parameters: {'rolling_volatility_window': 31, 'trix_period': 57, 'tema_period': 43, 'bbands_period': 27, 'macd_fast': 10, 'macd_slow': 36, 'obv_window': 47, 'ewma_span': 7, 'num_leaves': 48, 'learning_rate': 0.05794464516060516, 'n_estimators': 328, 'min_child_samples': 27, 'subsample': 0.7570747929505632, 'colsample_bytree': 0.7281645590829593, 'reg_alpha': 0.6378472469993524, 'reg_lambda': 0.37601835141425566}. Best is trial 17 with value: 10345.873730571659.
# [I 2025-05-04 23:50:57,459] Trial 21 finished with value: 10158.995057085385 and parameters: {'rolling_volatility_window': 54, 'trix_period': 45, 'tema_period': 54, 'bbands_period': 37, 'macd_fast': 9, 'macd_slow': 34, 'obv_window': 32, 'ewma_span': 3, 'num_leaves': 59, 'learning_rate': 0.06373505585331217, 'n_estimators': 233, 'min_child_samples': 23, 'subsample': 0.8238667653005987, 'colsample_bytree': 0.8553247458976886, 'reg_alpha': 0.8287019144217167, 'reg_lambda': 0.5302112812365848}. Best is trial 17 with value: 10345.873730571659.
# [I 2025-05-04 23:51:00,203] Trial 22 finished with value: 10275.570370810921 and parameters: {'rolling_volatility_window': 50, 'trix_period': 65, 'tema_period': 34, 'bbands_period': 34, 'macd_fast': 5, 'macd_slow': 29, 'obv_window': 22, 'ewma_span': 16, 'num_leaves': 44, 'learning_rate': 0.05481325771445295, 'n_estimators': 281, 'min_child_samples': 24, 'subsample': 0.6879383677674688, 'colsample_bytree': 0.8140747847302493, 'reg_alpha': 0.9044031311535321, 'reg_lambda': 0.7154569847740659}. Best is trial 17 with value: 10345.873730571659.
# [I 2025-05-04 23:51:04,588] Trial 23 finished with value: 10285.17388388613 and parameters: {'rolling_volatility_window': 57, 'trix_period': 52, 'tema_period': 53, 'bbands_period': 38, 'macd_fast': 8, 'macd_slow': 40, 'obv_window': 54, 'ewma_span': 6, 'num_leaves': 51, 'learning_rate': 0.044672334896945255, 'n_estimators': 373, 'min_child_samples': 18, 'subsample': 0.7630973217542729, 'colsample_bytree': 0.8698691694604648, 'reg_alpha': 0.6611131274757108, 'reg_lambda': 0.8062489769274916}. Best is trial 17 with value: 10345.873730571659.
# [I 2025-05-04 23:51:05,531] Trial 24 finished with value: 10197.45433537317 and parameters: {'rolling_volatility_window': 42, 'trix_period': 44, 'tema_period': 61, 'bbands_period': 35, 'macd_fast': 13, 'macd_slow': 31, 'obv_window': 40, 'ewma_span': 12, 'num_leaves': 39, 'learning_rate': 0.07127561611256553, 'n_estimators': 442, 'min_child_samples': 27, 'subsample': 0.7210170850257568, 'colsample_bytree': 0.6353760424835709, 'reg_alpha': 0.7431398319535293, 'reg_lambda': 0.6314956131176409}. Best is trial 17 with value: 10345.873730571659.
# [I 2025-05-04 23:51:05,889] Trial 25 pruned.
# [I 2025-05-04 23:51:08,454] Trial 26 finished with value: 10285.099327913245 and parameters: {'rolling_volatility_window': 53, 'trix_period': 67, 'tema_period': 50, 'bbands_period': 40, 'macd_fast': 16, 'macd_slow': 35, 'obv_window': 21, 'ewma_span': 31, 'num_leaves': 54, 'learning_rate': 0.06654216295535058, 'n_estimators': 230, 'min_child_samples': 13, 'subsample': 0.6618909822340239, 'colsample_bytree': 0.7240508849548281, 'reg_alpha': 0.7164907588121675, 'reg_lambda': 0.9072053804366261}. Best is trial 17 with value: 10345.873730571659.
# [I 2025-05-04 23:51:12,072] Trial 27 finished with value: 10141.889513289127 and parameters: {'rolling_volatility_window': 47, 'trix_period': 58, 'tema_period': 40, 'bbands_period': 28, 'macd_fast': 8, 'macd_slow': 27, 'obv_window': 35, 'ewma_span': 7, 'num_leaves': 47, 'learning_rate': 0.06156976972700199, 'n_estimators': 333, 'min_child_samples': 23, 'subsample': 0.7355060625489981, 'colsample_bytree': 0.8113204218189952, 'reg_alpha': 0.828706720803593, 'reg_lambda': 0.35287381289127584}. Best is trial 17 with value: 10345.873730571659.
# [I 2025-05-04 23:51:15,448] Trial 28 finished with value: 10292.748883338796 and parameters: {'rolling_volatility_window': 24, 'trix_period': 37, 'tema_period': 58, 'bbands_period': 35, 'macd_fast': 6, 'macd_slow': 23, 'obv_window': 43, 'ewma_span': 14, 'num_leaves': 61, 'learning_rate': 0.040559280161790674, 'n_estimators': 272, 'min_child_samples': 26, 'subsample': 0.8340617959019672, 'colsample_bytree': 0.8705638072081286, 'reg_alpha': 0.7699720465534996, 'reg_lambda': 0.5305830867554296}. Best is trial 17 with value: 10345.873730571659.
# [I 2025-05-04 23:51:18,612] Trial 29 finished with value: 10211.2011159669 and parameters: {'rolling_volatility_window': 34, 'trix_period': 16, 'tema_period': 70, 'bbands_period': 22, 'macd_fast': 12, 'macd_slow': 33, 'obv_window': 23, 'ewma_span': 10, 'num_leaves': 53, 'learning_rate': 0.056186742280172446, 'n_estimators': 308, 'min_child_samples': 30, 'subsample': 0.8013161389932576, 'colsample_bytree': 0.7337030638592202, 'reg_alpha': 0.6765227998965725, 'reg_lambda': 0.7654920515650541}. Best is trial 17 with value: 10345.873730571659.
# [I 2025-05-04 23:51:22,729] Trial 30 finished with value: 10248.619658717886 and parameters: {'rolling_volatility_window': 40, 'trix_period': 33, 'tema_period': 25, 'bbands_period': 32, 'macd_fast': 11, 'macd_slow': 37, 'obv_window': 28, 'ewma_span': 25, 'num_leaves': 36, 'learning_rate': 0.05113197706671979, 'n_estimators': 421, 'min_child_samples': 22, 'subsample': 0.7826951333610459, 'colsample_bytree': 0.6382235141596708, 'reg_alpha': 0.6225504732171232, 'reg_lambda': 0.6726506446199615}. Best is trial 17 with value: 10345.873730571659.
# [I 2025-05-04 23:51:26,030] Trial 31 finished with value: 10258.13960293443 and parameters: {'rolling_volatility_window': 26, 'trix_period': 41, 'tema_period': 58, 'bbands_period': 35, 'macd_fast': 6, 'macd_slow': 21, 'obv_window': 45, 'ewma_span': 18, 'num_leaves': 60, 'learning_rate': 0.04088966884515927, 'n_estimators': 274, 'min_child_samples': 26, 'subsample': 0.8419725309220376, 'colsample_bytree': 0.8769534317677142, 'reg_alpha': 0.7690198847601775, 'reg_lambda': 0.5416420877591759}. Best is trial 17 with value: 10345.873730571659.
# [I 2025-05-04 23:51:29,293] Trial 32 finished with value: 10255.663644505525 and parameters: {'rolling_volatility_window': 22, 'trix_period': 28, 'tema_period': 66, 'bbands_period': 38, 'macd_fast': 3, 'macd_slow': 24, 'obv_window': 54, 'ewma_span': 14, 'num_leaves': 70, 'learning_rate': 0.06808610284381371, 'n_estimators': 263, 'min_child_samples': 28, 'subsample': 0.7729096088466464, 'colsample_bytree': 0.8610966619783602, 'reg_alpha': 0.7189994289937996, 'reg_lambda': 0.49093755969522923}. Best is trial 17 with value: 10345.873730571659.
# [I 2025-05-04 23:51:32,548] Trial 33 finished with value: 10240.45691241003 and parameters: {'rolling_volatility_window': 23, 'trix_period': 37, 'tema_period': 50, 'bbands_period': 36, 'macd_fast': 9, 'macd_slow': 22, 'obv_window': 40, 'ewma_span': 15, 'num_leaves': 61, 'learning_rate': 0.030112726931726848, 'n_estimators': 225, 'min_child_samples': 25, 'subsample': 0.8285290789711783, 'colsample_bytree': 0.8967857726344051, 'reg_alpha': 0.6503111436055045, 'reg_lambda': 0.21844642759240734}. Best is trial 17 with value: 10345.873730571659.
# /usr/local/lib/python3.11/site-packages/numpy/_core/_methods.py:52: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# [I 2025-05-04 23:51:34,201] Trial 34 finished with value: 10358.88659838404 and parameters: {'rolling_volatility_window': 35, 'trix_period': 48, 'tema_period': 58, 'bbands_period': 10, 'macd_fast': 19, 'macd_slow': 33, 'obv_window': 53, 'ewma_span': 12, 'num_leaves': 56, 'learning_rate': 0.036838099760538145, 'n_estimators': 316, 'min_child_samples': 29, 'subsample': 0.797627027244591, 'colsample_bytree': 0.8283427145322887, 'reg_alpha': 0.9046730633229069, 'reg_lambda': 0.550441691411545}. Best is trial 34 with value: 10358.88659838404.
# [I 2025-05-04 23:51:37,354] Trial 35 finished with value: 10243.513791183585 and parameters: {'rolling_volatility_window': 42, 'trix_period': 48, 'tema_period': 13, 'bbands_period': 11, 'macd_fast': 19, 'macd_slow': 34, 'obv_window': 53, 'ewma_span': 11, 'num_leaves': 56, 'learning_rate': 0.03396823283559254, 'n_estimators': 301, 'min_child_samples': 29, 'subsample': 0.7932230426847002, 'colsample_bytree': 0.824590821016598, 'reg_alpha': 0.9255509107465776, 'reg_lambda': 0.8862877919544986}. Best is trial 34 with value: 10358.88659838404.
# [I 2025-05-04 23:51:40,983] Trial 36 finished with value: 10319.590350218781 and parameters: {'rolling_volatility_window': 34, 'trix_period': 54, 'tema_period': 51, 'bbands_period': 15, 'macd_fast': 19, 'macd_slow': 32, 'obv_window': 13, 'ewma_span': 8, 'num_leaves': 46, 'learning_rate': 0.03693772641774594, 'n_estimators': 333, 'min_child_samples': 21, 'subsample': 0.7939074931013225, 'colsample_bytree': 0.8465265137744549, 'reg_alpha': 0.9552026173136784, 'reg_lambda': 0.603404558114273}. Best is trial 34 with value: 10358.88659838404.
# [I 2025-05-04 23:51:44,118] Trial 37 finished with value: 10289.30186047661 and parameters: {'rolling_volatility_window': 33, 'trix_period': 55, 'tema_period': 45, 'bbands_period': 15, 'macd_fast': 19, 'macd_slow': 37, 'obv_window': 11, 'ewma_span': 5, 'num_leaves': 42, 'learning_rate': 0.037613058553459394, 'n_estimators': 328, 'min_child_samples': 19, 'subsample': 0.7980585854207921, 'colsample_bytree': 0.7879818362474991, 'reg_alpha': 0.9821450097663216, 'reg_lambda': 0.5924872893742228}. Best is trial 34 with value: 10358.88659838404.
# [I 2025-05-04 23:51:47,304] Trial 38 finished with value: 10274.718607998235 and parameters: {'rolling_volatility_window': 37, 'trix_period': 60, 'tema_period': 49, 'bbands_period': 17, 'macd_fast': 17, 'macd_slow': 31, 'obv_window': 15, 'ewma_span': 7, 'num_leaves': 46, 'learning_rate': 0.033535513172388884, 'n_estimators': 362, 'min_child_samples': 20, 'subsample': 0.7680704428221181, 'colsample_bytree': 0.8403719697241718, 'reg_alpha': 0.9744261314929938, 'reg_lambda': 0.4560310846365363}. Best is trial 34 with value: 10358.88659838404.
# [I 2025-05-04 23:51:50,283] Trial 39 finished with value: 10235.824970459655 and parameters: {'rolling_volatility_window': 30, 'trix_period': 47, 'tema_period': 33, 'bbands_period': 13, 'macd_fast': 17, 'macd_slow': 36, 'obv_window': 14, 'ewma_span': 8, 'num_leaves': 41, 'learning_rate': 0.03837000762696121, 'n_estimators': 290, 'min_child_samples': 21, 'subsample': 0.7849553456519582, 'colsample_bytree': 0.8266769792492659, 'reg_alpha': 0.9536809353772577, 'reg_lambda': 0.5642812673537004}. Best is trial 34 with value: 10358.88659838404.
# /usr/local/lib/python3.11/site-packages/numpy/_core/_methods.py:52: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# [I 2025-05-04 23:51:53,999] Trial 40 finished with value: 10219.476868835427 and parameters: {'rolling_volatility_window': 35, 'trix_period': 53, 'tema_period': 64, 'bbands_period': 10, 'macd_fast': 17, 'macd_slow': 30, 'obv_window': 19, 'ewma_span': 9, 'num_leaves': 50, 'learning_rate': 0.047837805863825876, 'n_estimators': 314, 'min_child_samples': 18, 'subsample': 0.8520584419934717, 'colsample_bytree': 0.7991624258002733, 'reg_alpha': 0.9466470411517787, 'reg_lambda': 0.6283578284719226}. Best is trial 34 with value: 10358.88659838404.
# [I 2025-05-04 23:51:57,423] Trial 41 finished with value: 10302.125198262425 and parameters: {'rolling_volatility_window': 56, 'trix_period': 42, 'tema_period': 60, 'bbands_period': 14, 'macd_fast': 19, 'macd_slow': 33, 'obv_window': 26, 'ewma_span': 5, 'num_leaves': 52, 'learning_rate': 0.04246996642191284, 'n_estimators': 340, 'min_child_samples': 22, 'subsample': 0.8117448488761015, 'colsample_bytree': 0.8818718964929544, 'reg_alpha': 0.8805006487129842, 'reg_lambda': 0.6961668348214365}. Best is trial 34 with value: 10358.88659838404.
# [I 2025-05-04 23:52:01,499] Trial 42 finished with value: 10258.537769366312 and parameters: {'rolling_volatility_window': 37, 'trix_period': 48, 'tema_period': 53, 'bbands_period': 16, 'macd_fast': 18, 'macd_slow': 32, 'obv_window': 33, 'ewma_span': 12, 'num_leaves': 56, 'learning_rate': 0.030752892609134275, 'n_estimators': 382, 'min_child_samples': 23, 'subsample': 0.8989391165494777, 'colsample_bytree': 0.8501567408112198, 'reg_alpha': 0.9164797833881205, 'reg_lambda': 0.8060037503912278}. Best is trial 34 with value: 10358.88659838404.
# [I 2025-05-04 23:52:03,180] Trial 43 finished with value: 10237.062072054212 and parameters: {'rolling_volatility_window': 44, 'trix_period': 67, 'tema_period': 46, 'bbands_period': 19, 'macd_fast': 15, 'macd_slow': 35, 'obv_window': 51, 'ewma_span': 3, 'num_leaves': 43, 'learning_rate': 0.03525891741131966, 'n_estimators': 317, 'min_child_samples': 21, 'subsample': 0.7274489400815503, 'colsample_bytree': 0.8999529243910876, 'reg_alpha': 0.8754988177215485, 'reg_lambda': 0.7697272388189862}. Best is trial 34 with value: 10358.88659838404.
# [I 2025-05-04 23:52:06,513] Trial 44 finished with value: 10289.694331027522 and parameters: {'rolling_volatility_window': 53, 'trix_period': 61, 'tema_period': 37, 'bbands_period': 23, 'macd_fast': 18, 'macd_slow': 32, 'obv_window': 30, 'ewma_span': 10, 'num_leaves': 48, 'learning_rate': 0.03883165472870901, 'n_estimators': 358, 'min_child_samples': 24, 'subsample': 0.7938371963933363, 'colsample_bytree': 0.8602378299163402, 'reg_alpha': 0.9259255511225791, 'reg_lambda': 0.6082555746708237}. Best is trial 34 with value: 10358.88659838404.
# /usr/local/lib/python3.11/site-packages/numpy/_core/_methods.py:52: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# [I 2025-05-04 23:52:10,732] Trial 45 finished with value: 10238.525928382041 and parameters: {'rolling_volatility_window': 28, 'trix_period': 57, 'tema_period': 56, 'bbands_period': 12, 'macd_fast': 13, 'macd_slow': 38, 'obv_window': 38, 'ewma_span': 13, 'num_leaves': 63, 'learning_rate': 0.061861234651485096, 'n_estimators': 401, 'min_child_samples': 28, 'subsample': 0.7545514904371771, 'colsample_bytree': 0.7771601376597821, 'reg_alpha': 0.8190360612456569, 'reg_lambda': 0.4921908956978183}. Best is trial 34 with value: 10358.88659838404.
# [I 2025-05-04 23:52:14,594] Trial 46 finished with value: 10287.781651260331 and parameters: {'rolling_volatility_window': 58, 'trix_period': 50, 'tema_period': 50, 'bbands_period': 20, 'macd_fast': 9, 'macd_slow': 26, 'obv_window': 56, 'ewma_span': 19, 'num_leaves': 38, 'learning_rate': 0.04448402483668122, 'n_estimators': 496, 'min_child_samples': 19, 'subsample': 0.7016001309375133, 'colsample_bytree': 0.7461205465182315, 'reg_alpha': 0.9667882630829586, 'reg_lambda': 0.6715137379207039}. Best is trial 34 with value: 10358.88659838404.
# /usr/local/lib/python3.11/site-packages/numpy/_core/_methods.py:52: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
